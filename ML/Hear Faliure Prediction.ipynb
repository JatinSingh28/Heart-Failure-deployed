# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("heart_failure_clinical_records_dataset.csv")
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction
# 0  70.0        0                      2695         1                 40  \
# 1  45.0        1                        66         1                 25
# 2  75.0        1                       203         1                 38
# 3  70.0        0                        81         1                 35
# 4  62.0        0                        30         1                 60
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex
# 0                    0   241000.0               1.0           137    1  \
# 1                    0   233000.0               0.8           135    1
# 2                    1   283000.0               0.6           131    1
# 3                    1   533000.0               1.3           139    0
# 4                    1   244000.0               0.9           139    1
#
#    smoking  time  DEATH_EVENT
# 0        0   247            0
# 1        0   230            0
# 2        1    74            0
# 3        0   212            0
# 4        0   117            0

# %%
col = df.columns
col
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.corr()['DEATH_EVENT'].sort_values()
# Out:
# time                       -0.511276
# ejection_fraction          -0.302391
# serum_sodium               -0.186342
# platelets                  -0.044250
# smoking                    -0.014120
# sex                         0.000607
# diabetes                    0.004943
# high_blood_pressure         0.040363
# creatinine_phosphokinase    0.072448
# anaemia                     0.075700
# age                         0.247136
# serum_creatinine            0.281244
# DEATH_EVENT                 1.000000
# Name: DEATH_EVENT, dtype: float64

# %%
# for i in df.columns:
#   plt.figure(figsize=(8,8))
#   sns.boxenplot(x = df['DEATH_EVENT'],y=df[i])
#   sns.stripplot(x = df['DEATH_EVENT'],y=df[i],color='BLACK')
#   plt.show

# %%
sns.kdeplot(x=df['time'],y=df['age'],hue=df['DEATH_EVENT'])
# Out:
# <Axes: xlabel='time', ylabel='age'>

# %%
x = df.drop(['DEATH_EVENT'],axis=1)
y = df['DEATH_EVENT']

# %%
# res = df.sample(n=100)

# %%
# df = pd.concat([df,res])

# %%
# df.shape
# Out:
# (798, 13)

# %%
# df = df.sample(n=len(df)-50).sort_index()

# %%
# df

# %%
# df = df.sample(frac = 1)

# %%
# df.to_csv("heart_failure_clinical_records_dataset.csv",index=False)

# %%
col = ['age',	'anaemia',	'creatinine_phosphokinase',	'diabetes',	'ejection_fraction',	'high_blood_pressure',	'platelets',	'serum_creatinine',	'serum_sodium',	'sex',	'smoking',	'time'	]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x = scaler.fit_transform(x)
x = pd.DataFrame(x,columns=col)

# %%
from joblib import dump
dump(scaler, 'std_scaler.bin', compress=True)
# Out:
# ['std_scaler.bin']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=42)

# %%
from keras import callbacks
from keras import Sequential
from keras.layers import Dense, Dropout
# from keras.optimizers import SGD

# %%
earlystopping = callbacks.EarlyStopping(
    min_delta =0.0001, patience = 20, restore_best_weights=True
)

# %%
model = Sequential()

# %%
model.add(Dense(units=256,kernel_initializer='uniform',activation='relu',input_dim=12))
model.add(Dense(units=128,kernel_initializer='uniform',activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(units=64,kernel_initializer='uniform',activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(units=32,kernel_initializer='uniform',activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,batch_size=32,epochs=500,callbacks=[earlystopping],validation_split=0.2)
# Out:
# Epoch 1/500
# 15/15 [==============================] - 3s 30ms/step - loss: 0.6901 - accuracy: 0.6904 - val_loss: 0.6841 - val_accuracy: 0.7000
# Epoch 2/500
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6515 - accuracy: 0.7238 - val_loss: 0.5799 - val_accuracy: 0.7000
# Epoch 3/500
# 15/15 [==============================] - 0s 9ms/step - loss: 0.4709 - accuracy: 0.7238 - val_loss: 0.4939 - val_accuracy: 0.7000
# Epoch 4/500
# 15/15 [==============================] - 0s 9ms/step - loss: 0.4017 - accuracy: 0.7238 - val_loss: 0.4572 - val_accuracy: 0.7000
# Epoch 5/500
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3875 - accuracy: 0.7531 - val_loss: 0.4730 - val_accuracy: 0.7833
# Epoch 6/500
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3488 - accuracy: 0.8452 - val_loss: 0.4387 - val_accuracy: 0.7833
# Epoch 7/500
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3166 - accuracy: 0.8849 - val_loss: 0.4436 - val_accuracy: 0.7667
# Epoch 8/500
# 15/15 [==============================] - 0s 8ms/step - loss: 0.2738 - accuracy: 0.9079 - val_loss: 0.4590 - val_accuracy: 0.8000
# Epoch 9/500
# 15/15 [==============================] - 0s 8ms/step - loss: 0.2476 - accuracy: 0.9079 - val_loss: 0.5002 - val_accuracy: 0.8083
# Epoch 10/500
# 15/15 [==============================] - 0s 8ms/step - loss: 0.2377 - accuracy: 0.9142 - val_loss: 0.5034 - val_accuracy: 0.8000
# Epoch 11/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2325 - accuracy: 0.9205 - val_loss: 0.4797 - val_accuracy: 0.7917
# Epoch 12/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2153 - accuracy: 0.9247 - val_loss: 0.4798 - val_accuracy: 0.8083
# Epoch 13/500
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1912 - accuracy: 0.9289 - val_loss: 0.5077 - val_accuracy: 0.8083
# Epoch 14/500
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1941 - accuracy: 0.9268 - val_loss: 0.5238 - val_accuracy: 0.8000
# Epoch 15/500
# 15/15 [==============================] - 0s 9ms/step - loss: 0.2003 - accuracy: 0.9205 - val_loss: 0.5073 - val_accuracy: 0.8083
# Epoch 16/500
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1863 - accuracy: 0.9289 - val_loss: 0.4934 - val_accuracy: 0.8167
# Epoch 17/500
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1721 - accuracy: 0.9268 - val_loss: 0.5079 - val_accuracy: 0.8250
# Epoch 18/500
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1775 - accuracy: 0.9289 - val_loss: 0.5243 - val_accuracy: 0.8250
# Epoch 19/500
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1734 - accuracy: 0.9310 - val_loss: 0.5007 - val_accuracy: 0.8167
# Epoch 20/500
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1576 - accuracy: 0.9351 - val_loss: 0.5073 - val_accuracy: 0.8417
# Epoch 21/500
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1372 - accuracy: 0.9393 - val_loss: 0.5082 - val_accuracy: 0.8500
# Epoch 22/500
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1281 - accuracy: 0.9435 - val_loss: 0.5301 - val_accuracy: 0.8500
# Epoch 23/500
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1030 - accuracy: 0.9561 - val_loss: 0.5820 - val_accuracy: 0.8333
# Epoch 24/500
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1053 - accuracy: 0.9540 - val_loss: 0.5883 - val_accuracy: 0.8583
# Epoch 25/500
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0889 - accuracy: 0.9644 - val_loss: 0.5935 - val_accuracy: 0.8667
# Epoch 26/500
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1084 - accuracy: 0.9561 - val_loss: 0.5886 - val_accuracy: 0.8667

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print(val_accuracy*100)
# Out:
# 80.03205152658316

# %%
y_pred = model.predict(x_test)
y_pred = (y_pred>0.5)
# Out:
# 7/7 [==============================] - 0s 3ms/step

# %%
eval = model.evaluate(x_test,y_test)
# Out:
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3635 - accuracy: 0.8750

# %%
print("Accuracy: ",round(eval[1],2))
# Out:
# Accuracy:  0.88

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

model.save_weights("model.h5")
